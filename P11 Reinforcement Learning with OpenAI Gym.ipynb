# %% [markdown]
# Introduction to Reinforcement Learning and OpenAI Gym

# %% [markdown]
# - We use OpenAI Gym to create the CartPole environment.
# - The agent takes random actions and interacts with the environment.
# - We observe the number of steps before the episode ends.

# %%
import gym

Create and initialize the CartPole environment
env = gym.make("CartPole-v1")

env.reset()

total_episodes = 5  # Number of episodes to run

for episode in range(total_episodes):
    state = env.reset()
    done = False
    step_count = 0

    while not done:
        env.render()  # Render the environment
        action = env.action_space.sample()  # Take a random action
        state, reward, done, info = env.step(action)
        step_count += 1

    print(f"Episode {episode+1} finished after {step_count} timesteps")

env.close()
# Out:
# Episode 1 finished after 33 timesteps
# Episode 2 finished after 59 timesteps
# Episode 3 finished after 24 timesteps
# Episode 4 finished after 20 timesteps
# Episode 5 finished after 17 timesteps

# %% [markdown]
# ## **Exercise:**
#
# Enhance this practical exercise to print the state, action, and reward at each step.
#
# Hints: Add print statements inside the while loop to track the agent's interaction.

# %% [markdown]
# Lunar lander exercise: https://www.kaggle.com/code/naresh/lunar-lander
